# %%
from flask import Flask, render_template, request, jsonify

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipcart_url="https://www.flipkart.com/search?q="+"iphone11" ## we can change product name as needed

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
response_website= urReq(flipcart_url)  # here we have retrive the viewpage resourse code

# %%
#response_website.read()   ##this is read function of view-resouce page of flipkart website

# %%
data_flipcart=response_website.read()

# %%
beautified_html=bs(data_flipcart,"html.parser")    ## html.parser is used to assign the format of data

# %%
# beautified_html.find_all('div',{"class":"_1AtVbE col-12-12"})

# %%
len(beautified_html.find_all('div',{"class":"_1AtVbE col-12-12"}))
# Out:
# 30

# %%
bigbox=beautified_html.find_all('div',{"class":"_1AtVbE col-12-12"}) 
#this is to find mentioned perticular class# which is for searching of phones

# %%
bigbox[6].div.div.div.a['href']
# Out:
# '/apple-iphone-11-green-64-gb/p/itm386a85013a3d1?pid=MOBFWQ6BHPMG29QM&lid=LSTMOBFWQ6BHPMG29QMMGHL6F&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&spotlightTagId=FkPickId_tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=04abfc16-e34a-48fe-a1f8-1d4f748665c2.MOBFWQ6BHPMG29QM.SEARCH&ppt=None&ppn=None&ssid=m4i1tkr8xs0000001691588817847&qH=d6db477051465f9a'

# %%
"https://www.flipkart.com"+bigbox[6].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/apple-iphone-11-green-64-gb/p/itm386a85013a3d1?pid=MOBFWQ6BHPMG29QM&lid=LSTMOBFWQ6BHPMG29QMMGHL6F&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&spotlightTagId=FkPickId_tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=04abfc16-e34a-48fe-a1f8-1d4f748665c2.MOBFWQ6BHPMG29QM.SEARCH&ppt=None&ppn=None&ssid=m4i1tkr8xs0000001691588817847&qH=d6db477051465f9a'

# %%
product6="https://www.flipkart.com"+bigbox[6].div.div.div.a['href']

# %% [markdown]
# Till here we have pulled out link of href of web to click on perticular phone

# %%
requests.get(product6)   ## here we have clicked on link preapared under product6
# Out:
# <Response [200]>

# %%
product66=requests.get(product6)   ## here we are on product6 webpage

# %%
product66.encoding="utf-8"   
##This is likely used in a web scraping context to ensure that the content retrieved from a website is properly decoded and interpreted using the UTF-8 character encoding.

# %%
product6_page=bs(product66.text,"html.parser")   # here we have beautify the code of product 6 page

# %%
# product6_page.find_all("div", {"class":"_16PBlm"})    ## this is to find mentioned perticular class# which is for reviews

# %%
product6_page.find_all("div", {"class":"_16PBlm"})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Classy product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Camera is awesome<br/>Best battery backup<br/>A performer 👌🏻<br/>It will be a real value for money if they provide charger and earphone inbox!</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202104/blobio-imr-202104_627227119ef94b9281f50e8c52d528cf.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Vishnu Ramakrishnan</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M
# ...

# %%
product6_reviews=product6_page.find_all("div", {"class":"_16PBlm"})

# %%
len(product6_reviews)
# Out:
# 11

# %%
# rating=product6_reviews[5].div.div.div.find_all("div",{"class":"_3LWZlK _1BLPMq"}).text    
# this upper code will show error becouse find_all function provide data in list format
rating=product6_reviews[5].div.div.div.find_all("div",{"class":"_3LWZlK _1BLPMq"})[0].text

# %%
rating
# Out:
# '5'

# %%
name=product6_reviews[5].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
name
# Out:
# 'Vikram rapolu'

# %%
comment_header=product6_reviews[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Just wow!'

# %%
comment=product6_reviews[5].div.find_all("div",{"class":""})[1].text

# %%
comment
# Out:
# 'Perfect Product!!'

# %%
date=product6_reviews[5].div.find_all("p",{"class":"_2sc7ZR"})[1].text

# %%
date
# Out:
# 'Aug, 2020'

# %%
price= product6_page.div.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
price
# Out:
# '₹41,999'

# %%
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
import pandas as pd

# %%
price= []
name= []
comment_header=[]
comment=[]
rating=[]
date= []

for i in range(len(product6_reviews)+1):
    price.append(product6_page.div.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text)
    name.append(product6_reviews[i].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
    comment_header.append(product6_reviews[i].div.div.div.p.text)
    comment.append(product6_reviews[i].div.find_all("div",{"class":""})[1].text)
    rating.append(product6_reviews[i].div.div.div.find_all("div",{"class":"_3LWZlK _1BLPMq"})[0].text)
    date.append(product6_reviews[i].div.find_all("p",{"class":"_2sc7ZR"})[1].text)
    
    print(price, name, comment_header, comment, rating, date )
    print()
# Out:
# ['₹41,999'] ['Vishnu Ramakrishnan'] ['Classy product'] ['Camera is awesomeBest battery backupA performer 👌🏻It will be a real value for money if they provide charger and earphone inbox!'] ['5'] ['Apr, 2021']
#
# ['₹41,999', '₹41,999'] ['Vishnu Ramakrishnan', 'siva sankar'] ['Classy product', 'Mind-blowing purchase'] ['Camera is awesomeBest battery backupA performer 👌🏻It will be a real value for money if they provide charger and earphone inbox!', 'Photos super'] ['5', '5'] ['Apr, 2021', '2 months ago']
#
# ['₹41,999', '₹41,999', '₹41,999'] ['Vishnu Ramakrishnan', 'siva sankar', 'Manish  Deshlahare'] ['Classy product', 'Mind-blowing purchase', 'Terrific'] ['Camera is awesomeBest battery backupA performer 👌🏻It will be a real value for money if they provide charger and earphone inbox!', 'Photos super', 'Very very good'] ['5', '5', '5'] ['Apr, 2021', '2 months ago', 'Jul, 2020']
#
# ...

# %%
len(price)

price=price[0:10]   ## this i have done becouse price length was comming more, not sure why.

# %%
## here i have converted data into dataframe to change in CSV format

review_data={
    "price":price, 
    "name": name,
    "comment_header":comment_header,
    "comment":comment,
    "rating":rating,
    "date":date
}

df=pd.DataFrame(review_data)

# %%
df.to_csv(r"C:\Users\sumit\OneDrive\Desktop\Data Science Folder\FSDS 2022\API\Flipkart_Review-Data_Scraping_Project\flipcart_scrapped_reviews.csv",index=False)

# %%
pd.read_csv(r"C:\Users\sumit\OneDrive\Desktop\Data Science Folder\FSDS 2022\API\Flipkart_Review-Data_Scraping_Project\flipcart_scrapped_reviews.csv")

# %%
import mysql.connector as conn
mydb=conn.connect(host='localhost', user='root', passwd='12345')
cursor=mydb.cursor()
cursor.execute("create database if not exists ScrappingDB")

# %%
# I have uploaded flipcart_scrapped_reviews.csv file in jupyter notebook
import MySQLdb
#!pip install csvkit
import csvkit as csv
# !csvsql --db mysql://root:12345@127.0.0.1:3306/ScrappingDB --insert flipcart_scrapped_reviews.csv
